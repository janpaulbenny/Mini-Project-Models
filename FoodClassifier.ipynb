# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True # This bypasses the OSError

import tensorflow as tf
# ... rest of your code ...

# 1. Configuration
IMG_SIZE = (224, 224)
BATCH_SIZE = 16

# 2. Data Loading (Points to parent folders only)
train_gen = ImageDataGenerator(rescale=1./255, horizontal_flip=True, zoom_range=0.2)
val_gen = ImageDataGenerator(rescale=1./255)

train_path = r"C:\Users\JAN\Downloads\beef_data\dataset\train"
val_path = r"C:\Users\JAN\Downloads\beef_data\dataset\val"

# Use a dot '.' to mean "look right here in this folder"
#train_path = "./dataset/train" 
#val_path = "./dataset/val"

train_data = train_gen.flow_from_directory(train_path, target_size=IMG_SIZE, batch_size=BATCH_SIZE, class_mode="categorical")
val_data = val_gen.flow_from_directory(val_path, target_size=IMG_SIZE, batch_size=BATCH_SIZE, class_mode="categorical")

# 3. Model Architecture (MobileNetV2 Transfer Learning)
base_model = tf.keras.applications.MobileNetV2(input_shape=(224, 224, 3), include_top=False, weights="imagenet")
base_model.trainable = False 

model = models.Sequential([
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.3),
    layers.Dense(train_data.num_classes, activation='softmax') # Will be 2: Beef and Others
])

# 4. Compile and Train
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.fit(train_data, validation_data=val_data, epochs=10)

# 5. Save the "Brain"
model.save("food_classifier_model.h5")
print("Model Saved Successfully!")
# Out:
# Found 1100 images belonging to 2 classes.
# Found 277 images belonging to 2 classes.
# Epoch 1/10
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 28s 340ms/step - accuracy: 0.9818 - loss: 0.0554 - val_accuracy: 1.0000 - val_loss: 0.0065
# Epoch 2/10
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 21s 306ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 1.0000 - val_loss: 0.0034
# Epoch 3/10
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 22s 312ms/step - accuracy: 1.0000 - loss: 3.6857e-04 - val_accuracy: 0.9964 - val_loss: 0.0047
# Epoch 4/10
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 22s 320ms/step - accuracy: 0.9991 - loss: 0.0033 - val_accuracy: 0.9964 - val_loss: 0.0075
# Epoch 5/10
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 21s 308ms/step - accuracy: 0.9991 - loss: 0.0023 - val_accuracy: 0.9928 - val_loss: 0.0132
# Epoch 6/10
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 21s 309ms/step - accuracy: 0.9991 - loss: 0.0023 - val_accuracy: 0.9856 - val_loss: 0.0329
# Epoch 7/10
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 22s 313ms/step - accuracy: 0.9991 - loss: 0.0031 - val_accuracy: 0.9928 - val_loss: 0.0200
# Epoch 8/10
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 21s 308ms/step - accuracy: 1.0000 - loss: 4.2648e-04 - val_accuracy: 0.9964 - val_loss: 0.0062
# Epoch 9/10
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 21s 305ms/step - accuracy: 1.0000 - loss: 3.0569e-05 - val_accuracy: 0.9964 - val_loss: 0.0067
# Epoch 10/10
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 21s 305ms/step - accuracy: 1.0000 - loss: 2.5530e-05 - val_accuracy: 0.9964 - val_loss: 0.0068
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model Saved Successfully!

# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras.preprocessing import image
import os

# 1. Load the "Brain" you just trained
model = tf.keras.models.load_model('food_classifier_model.h5')

# 2. Configuration
IMG_SIZE = (224, 224)
THRESHOLD = 0.85  # 85% confidence required

def predict_food(img_path):
    # Load and preprocess the image
    #img = image.load_img(img_path, target_size=IMG_SIZE)
    img = image.load_img(img_path, target_size=(224, 224), interpolation='bilinear')
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0) # Make it a "batch" of 1
    img_array /= 255.0  # Normalize like we did in training

    # Run Prediction
    predictions = model.predict(img_array, verbose=0)[0]
    
    # Assuming folder order was: [0] beef, [1] others
    # (Keras flow_from_directory uses alphabetical order)
    beef_confidence = predictions[0]
    others_confidence = predictions[1]

    print(f"\n--- Results for: {os.path.basename(img_path)} ---")
    print(f"Beef Confidence: {beef_confidence:.2%}")
    print(f"Others Confidence: {others_confidence:.2%}")

    # 3. Decision Logic for your Product
    if beef_confidence >= THRESHOLD:
        return "RESULT: [BEEF] - Proceeding to Freshness Analysis (Gas Sensors)."
    else:
        return "RESULT: [NOT AVAILABLE] - Food item not recognized or incorrect type."

# 4. TEST IT: Pick one image from your val/beef folder
test_image = r"C:\Users\JAN\Downloads\beef_data\dataset\val\beef\additional_beef.jpg" 

# Check if file exists before running
if os.path.exists(test_image):
    print(predict_food(test_image))
else:
    print("Error: Please replace 'ANY_IMAGE_NAME.jpg' with a real filename from your folder.")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x0000028E4DC65480> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x0000028E4DC65480> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# --- Results for: additional_beef.jpg ---
# Beef Confidence: 8.16%
# Others Confidence: 91.84%
# RESULT: [NOT AVAILABLE] - Food item not recognized or incorrect type.

# %%
import tensorflow as tf

# Load the brain
model = tf.keras.models.load_model('food_classifier_model.h5')

# Convert to TFLite
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()

# Save the converted model
with open('food_classifier_model.tflite', 'wb') as f:
    f.write(tflite_model)

print("✅ Success! Your model is now an Edge-Ready .tflite file.")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: C:\Users\JAN\AppData\Local\Temp\tmpxwfjq1r5\assets
# INFO:tensorflow:Assets written to: C:\Users\JAN\AppData\Local\Temp\tmpxwfjq1r5\assets
# Saved artifact at 'C:\Users\JAN\AppData\Local\Temp\tmpxwfjq1r5'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='input_layer_3')
# Output Type:
#   TensorSpec(shape=(None, 2), dtype=tf.float32, name=None)
# Captures:
#   2670480541120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670480552912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670480555024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670480548336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670480550624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670480551328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670480656160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670480654752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670480656336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670480657568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670480546048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670480660560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670480658272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670480658624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670480661440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670480664080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670480664432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670480666016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670480662496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670480665312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670480668128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670480668304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670480670064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670480666896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670480669360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670480666720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670480753936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670480753760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670480755520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670480755344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670480667600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670480758336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670480756048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670480756400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670480759216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670480761856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670480762032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670480763792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670480760624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670480763088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670480765728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670480765904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670480767664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670480764496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670480766960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670480768016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670480868096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670480867920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670480752880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670480869504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670480756928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670480872672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670480870208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670480869152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670480873552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670480876192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670480876368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670480878128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670480874960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670480877424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670480880064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670480880240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670480882000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670480878832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670480881296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670480879536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670500806896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670500807248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670480880944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670500806720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670480881120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670500811296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670500809008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670500809360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670500812176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670500814992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670500815168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670500810416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670500813760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670500816224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670500818864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670500819040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670500820800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670500817632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670500820096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670500818336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670500820624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670500813408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670500819744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670500905728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670500819392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670500909248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670500906784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670500905024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670500910128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670500912944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670500913120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670500907488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670500911712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670500914176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670500916816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670500916992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670500918752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670500915584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670500918048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670500916288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670500918576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670500915408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670500917696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670500971440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670500912064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670500974256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670500971968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670500972320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670500975136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670500977776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670500977952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670500973376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670500976544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670500979008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670500981824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670500982000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670500983760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670500980592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670500983056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670500985696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670500983584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670500983232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670500984640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670500984992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670500984112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501121184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501118896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501119248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501122064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670500984288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501125232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501118016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501121712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501126112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501128752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501128928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501130688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501127520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501129984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501132624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501120128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501127344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501128048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501133152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501131920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501202752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501199936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501202400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501203632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501131216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501206624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501200288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501204688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501207504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501210144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501210320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501212080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501208912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501211376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501214016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501214192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501215952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501212784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501215248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501201344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501267056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501265648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501268816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501268464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501210672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501271456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501269168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501269520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501272336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501275152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501275328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501277088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501273920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501276384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501279024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501279200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501280960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501277792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501280256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501277616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501348448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501348272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501350032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501349856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501279728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501353024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501350560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501349504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501353904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501356720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501356896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501358656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501355488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501357952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501360592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501360768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501362528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501359360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501361824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501359184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501446400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501446224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501355664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501447808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501357424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501450800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501448512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501448864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501451680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501454320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501454496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501456256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501453088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501455552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501458368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501458544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501460304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501457136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501459600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501456960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501544176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501544528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501459248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501544000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501447984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501548576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501546288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501546640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501549456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501552272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501552448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501547696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501551040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501553504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501556144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501556320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501558080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501554912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501557376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501555616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501557904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501550688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501557024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501643008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501554736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501646352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501644064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501644416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670501647232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670478429872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670478428640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670478438320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2670478476560: TensorSpec(shape=(), dtype=tf.resource, name=None)
# ✅ Success! Your model is now an Edge-Ready .tflite file.

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing import image

# 1. Load the TFLite model and allocate tensors
interpreter = tf.lite.Interpreter(model_path="food_classifier_model.tflite")
interpreter.allocate_tensors()

# 2. Get input and output details (tells the code where the "doors" are)
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

def predict_tflite(img_path):
    # 3. Preprocess the image exactly like before
    img = image.load_img(img_path, target_size=(224, 224))
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0).astype(np.float32)
    img_array /= 255.0

    # 4. Set the input tensor
    interpreter.set_tensor(input_details[0]['index'], img_array)

    # 5. Run the "Inference" (the actual calculation)
    interpreter.invoke()

    # 6. Get the result
    predictions = interpreter.get_tensor(output_details[0]['index'])[0]
    
    beef_conf = predictions[0]
    return beef_conf

# Test it
test_path = r"C:\Users\JAN\Downloads\beef_data\dataset\val\beef\20210917_B01_10_seg.jpg"
result = predict_tflite(test_path)

THRESHOLD = 0.60 # Your new optimized threshold

print(f"\n--- TFLite Test Results ---")
print(f"Beef Confidence: {result:.2%}")

if result >= THRESHOLD:
    print("✅ RESULT: [BEEF DETECTED] - Proceeding to sensor analysis.")
else:
    print("❌ RESULT: [NOT RECOGNIZED] - System standby.")
# Out:
# --- TFLite Test Results ---
# Beef Confidence: 99.78%
# ✅ RESULT: [BEEF DETECTED] - Proceeding to sensor analysis.
